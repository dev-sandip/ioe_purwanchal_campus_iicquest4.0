# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df1=pd.read_csv('../data_cleaned/clean.csv')
# df2=pd.read_csv('../data_cleaned/clean.txt')

# %%
df1.head()
# Out:
#                                          source_file  \
# 0  /linux-data/projects/ioe_purwanchal_campus_iic...
# 1  /linux-data/projects/ioe_purwanchal_campus_iic...
# 2  /linux-data/projects/ioe_purwanchal_campus_iic...
# 3  /linux-data/projects/ioe_purwanchal_campus_iic...
# 4  /linux-data/projects/ioe_purwanchal_campus_iic...
#
#                                                 text
# 0  यसरी व्यवस्थापन गर्दैछ बिपी कोइराला क्यान्सर अ...
# 1  प्रत्यारोपणमा उपयोग हुने वस्तु सरकारी फार्मेसी...
# 2  मेचीनगरमा ‘अफ्रिकन स्वाइन फ्लू’ र ‘लम्पी स्किन...
# 3  अलपत्र भएका आधारभूत अस्पताल साउनबाटै सञ्चालनमा...
# 4  कालीमाटीमा भित्रिएका १७४ प्रकारका तरकारीमा विषादी

# %%
df1.drop("source_file",axis=1,inplace=True)

# %%
df1.head()
# Out:
#                                                 text
# 0  यसरी व्यवस्थापन गर्दैछ बिपी कोइराला क्यान्सर अ...
# 1  प्रत्यारोपणमा उपयोग हुने वस्तु सरकारी फार्मेसी...
# 2  मेचीनगरमा ‘अफ्रिकन स्वाइन फ्लू’ र ‘लम्पी स्किन...
# 3  अलपत्र भएका आधारभूत अस्पताल साउनबाटै सञ्चालनमा...
# 4  कालीमाटीमा भित्रिएका १७४ प्रकारका तरकारीमा विषादी

# %%
combined = pd.concat([df1, df2], axis=0)

# %%
combined.shape
# Out:
# (1488300, 2)

# %%
combined.head()
# Out:
#                                                 text source_file
# 0  यसरी व्यवस्थापन गर्दैछ बिपी कोइराला क्यान्सर अ...         NaN
# 1  प्रत्यारोपणमा उपयोग हुने वस्तु सरकारी फार्मेसी...         NaN
# 2  मेचीनगरमा ‘अफ्रिकन स्वाइन फ्लू’ र ‘लम्पी स्किन...         NaN
# 3  अलपत्र भएका आधारभूत अस्पताल साउनबाटै सञ्चालनमा...         NaN
# 4  कालीमाटीमा भित्रिएका १७४ प्रकारका तरकारीमा विषादी         NaN

# %%
combined.drop("source_file",axis=1,inplace=True)

# %%
combined.head()
# Out:
#                                                 text
# 0  यसरी व्यवस्थापन गर्दैछ बिपी कोइराला क्यान्सर अ...
# 1  प्रत्यारोपणमा उपयोग हुने वस्तु सरकारी फार्मेसी...
# 2  मेचीनगरमा ‘अफ्रिकन स्वाइन फ्लू’ र ‘लम्पी स्किन...
# 3  अलपत्र भएका आधारभूत अस्पताल साउनबाटै सञ्चालनमा...
# 4  कालीमाटीमा भित्रिएका १७४ प्रकारका तरकारीमा विषादी

# %%
combined.to_csv("combined.csv", index=False)
